# %% [markdown]
# # Lets Grow More (LGMVIP) - "DATA SCIENCE INTERN"

# %% [markdown]
# ### BEGINNER LEVEL TASK

# %% [markdown]
# ### TASK-3- Image to Pencil Sketch with Python:

# %% [markdown]
# # Importing openCV2 Library

# %%
import cv2

# %% [markdown]
# # Read the image

# %%
image1 = cv2.imread("powerpuff.jpg")
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=564x401 at 0x7F66D4FBB040>
# -1

# %% [markdown]
# ![BIRD1-LGMVIP.PNG](attachment:BIRD1-LGMVIP.PNG)

# %%
image2 = cv2.imread("sunflower.jpg")
from google.colab.patches import cv2_imshow
cv2_imshow(image2)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=474x842 at 0x7F66D4F68520>
# -1

# %% [markdown]
# # Creating a new image by converting the original image to greyscale

# %%
gray_image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray_image1)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=564x401 at 0x7F66D4FBB040>
# -1

# %%
gray_image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
from google.colab.patches import cv2_imshow
cv2_imshow(gray_image2)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=474x842 at 0x7F66D4FBA9B0>
# -1

# %% [markdown]
# # Inverting the new grayscale image

# %%
inverted_image1 = 255 - gray_image1
from google.colab.patches import cv2_imshow
cv2_imshow( inverted_image1)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=564x401 at 0x7F66D4FBB4C0>
# -1

# %%
inverted_image2 = 255 - gray_image2
from google.colab.patches import cv2_imshow
cv2_imshow (inverted_image2)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=474x842 at 0x7F66D4FBA410>
# -1

# %% [markdown]
# #  Bluring the image by using the Gaussian Function in OpenCV

# %%
blurred1 = cv2.GaussianBlur(inverted_image1, (21, 21), 0)

# %%
blurred2 = cv2.GaussianBlur(inverted_image2, (21, 21), 0)

# %% [markdown]
# # Inverting the blurred image and then we can easily convert the image into a pencil sketch

# %%
inverted_blurred1 = 255 - blurred1
pencil_sketch1 = cv2.divide(gray_image1, inverted_blurred1, scale=256.0)
from google.colab.patches import cv2_imshow
cv2_imshow(pencil_sketch1)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=564x401 at 0x7F66D5099DE0>
# -1

# %% [markdown]
# ![BIRD-PENCIL-LGMVIP.PNG](attachment:BIRD-PENCIL-LGMVIP.PNG)

# %%
inverted_blurred2 = 255 - blurred2
pencil_sketch2 = cv2.divide(gray_image2, inverted_blurred2, scale=256.0)
from google.colab.patches import cv2_imshow
cv2_imshow( pencil_sketch2)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=474x842 at 0x7F66D4FBAC50>
# -1

# %% [markdown]
# ![GIRL-PENCIL-LGMVIP.PNG](attachment:GIRL-PENCIL-LGMVIP.PNG)

# %% [markdown]
# # looking at both the original image and the pencil sketch

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
cv2_imshow(pencil_sketch1)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=564x401 at 0x7F66D4FBB3D0>
# <PIL.Image.Image image mode=L size=564x401 at 0x7F66D4FBA200>
# -1

# %% [markdown]
# ![Bird-LGMVIP.PNG](attachment:Bird-LGMVIP.PNG)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow (image2)
cv2_imshow( pencil_sketch2)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=474x842 at 0x7F66D4FBBBE0>
# <PIL.Image.Image image mode=L size=474x842 at 0x7F66D4FBA230>
# -1

# %% [markdown]
# ![GIRL-LGMVIP.PNG](attachment:GIRL-LGMVIP.PNG)
